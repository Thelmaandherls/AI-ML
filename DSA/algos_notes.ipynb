# %% [markdown]
# ##### Introduction to Algorithm - Playing a Counting Game

# %% [markdown]
# Algorithm = set of steps a program takes to complete a task
# Problems in cs have solutions that do the job well for a given taks
# There is an established body of knowledge to solve specific probelms well
# Part of understanding algos is not just knowing that it exists, but knowing when to apply it, which requires understanding the problem
# Algorithmic thinking is looking at a problem, breaking it into tasks and then deciding which algo is best to solve the problem -> better understanding of complexity and efficiency in programming
# Aim is to break an indurmountable problem into distinct components and indentify the right tools to solve each distinct component
#
# Game:
# num b/w 1-10. Guess the num. When they guess, tell them if it's too high r low. Winner is the one with the fewest guess. This is an example of searching for a value aka search algos
#
# Important parts of algo thinking
# 1. Important to establish the probelm set and what values count as inputs - aka establish the boundaries of the problem
# 2. With any given prob, there's no one best solution, rather the aim is to figure out which solution works best for the current prob
# 3. The specific val being searched for may not matter as much as where that val lies in the given range
# 4. the speed at which the prob is solved really matters
# 5. An important first step to def the aglo isn't the algo itself, but the prob that I want to solve
# 6. Algo uses the same steps to solve the prob every time it's solved
#
# Guideline for algos which makes for good algo thinking
# 1. Must have a clear prob statement, input and output  - specifiy how the input is def and what the output looks like when the algo has done it's job
# 2. An algos def must contain a specific set of instructions in a specific order - order of execution needs to be clear
# 3. Each step msut not be complex, but explicity clear - it shouldn't be able to be broken down into more substeps - each steo should be distinct
# 4. Should produce a result to understand the behaviour
# 5. Algo should complete and not have an infinite timeline - complete in a finite amount of time
# 6. Executing the steps of an algo for a given input must result in the same output every time
#
# How to approach a problem
# 1. Work through each of the guidelines
# 2. Break the prob into any possible N of smaller probes where each prob can be clearly def in terms of input and outputs
# 3. Def the prob, input and output before def the algo
#
# Good algos
# 1. Correctness -if for every val in the input data, always get an output + the algo should always terminate for every algo - proved by mathetical induction which involves writing a specification and correctness proof
# 2. Efficiency - solve probs fasters and deliver better experience - measured in time and space complexity. time complexity = how long it takes the algo to run - less time = more efficient. Space complexity - how much memory is taken up. Good algos need to have a balance of time and sapce complexity. These are measured using the Big O notation
# - running time of the algo - how long the algo runs for a given set of vals
#
# Ways to eval algos
# 1. Best case
# 2. Avg case - avg running time - not accurate
# 3. Worst case - Max of the range - indicates that the algowill never perform worse than expected
#
# Types of search algos
# 1. Linear search - start at the beginning and then add 1 num  - aka sequential / simple search
#     - it's an algo because of the specificity of how it's def : we start at the beginning of the given range in the list , if the value != target value, move one by 1 sequentially until target is met
#     - input = series of values. output = target value )can be nothing)
#     - for a given value of n in a linear search, it will take n tries
#     - doesn't matter if value is not sorted
# 2. Binary search - values need to be sorted - start in the middle and then dsicard the half that does not satify the condition, keep decreasing by half and evaluating
#     - returns postion in the list as to where the target value is as we already know the target value
#     - input = sorted list of values
#     - output = position in the lsit of target value or sme sort of value to indicate that the target val does not exist in the list
#     - determine the middle psotion of the sorted list
#     - comapre the middle element to the target element
#     - if elements match, return the middle psotion and the value
#     - if they don't match, check of the element in the middle position is smaller than the target element, if it is, go back to step 2
#     - if it's larger than the target element, go back to step 2 where the new list is from the start of the old list and ends in the middle of the old list, and then go to the middle of this new list
#     - repeat these steps until the target element is found or until a sublist contains only one element - if the single element sublist  does not match the target element , end the algo, indicating that the element does not exist in the list

# %% [markdown]
# ##### Introduction to Algorithms - Time Complexity

# %% [markdown]
# 1. Evaluating the efficiency of binary search
#     - Looking at efficiney in terms of time complexity = eval how the algo performs in the worst case scenario
#     - Given a series of data, if the target val is near the front of the list, then linear search may perform just as well or slightly better than binary search
#     - When measuring efficiecny, use worst case scenario as benchmark as it can never perform worse than the worst case
#     - As n increase, binary search performs significantly better, when n = 1k bs=10operations / tries, when n = 10k bs = 14, when n = 100k bs =17 operations - these are plotted on a graph as the growth rate / order of growth
#     - Order of growth / growth rate gives a better picture if the performance of diff algos as it shows us how the algo will hold up as n grows larger - known as Big (O)
#     - Big O = theoretical definition of the complexity of an algo as a function of the size - it's a notation used to describe complexity. Notation means that everything is simplified down into a single variable
#     An example of complexity written interms of big o looks like: O(n)
#     O comes from: order of magnitude of complexity - basically a measure of efficiency -just reading this var for specific algos should give us a good judgement of the efficiency of the algo
#     - Complexity is releative - when we eval the complexity of of the bs algo, we do it relative to other search algos, not all
#     - Big O is useful for understanding time and space complexity for algos that solve the same problem
#     - Big O is a func of size thf it measures complexity as the input size grows - it's importnat to underdstand how algo performs on all possible datasets
#     - Big O = also refreed to as the upper bound of an algo - measures how the algo performs in the worst case scenaio
#
# 2. Assumed so far that the algo as a whole has a single measure of complexity which is not true - each step in the algo has it's own space and time complexity
#
# 3. Big O for specific algos
#     - Linear search has a time complexity of O(n)
#     - Binary Search has a time complexity of O(log n)
#     - O(1) = constant time - where the time taken to run a specific operation / step doesn't chnage e.g. in linear search, when the current value is being compared to the target - the size of the dataset doens't matter as we're already at the current value - therefore this doesn't change in any - thf reading a val in a list = constant time operation = O(1) = most ideal case as input size doesn't matter and algo run time will remain the same
#     - Everytime we double the value of n, the number of steps it takes to dec the list to a single element, only increases by 1 - this is calleda logarithm of n
#     - In bs, for a given val of n, the num of tries it takes to find the worst case scenario = log2 of n+1 (not t the base of 2 of n + 1) - thf is is a logarithmic runtime and noted as O(log n) = O(ln n) - as n grows really large, the num of operations initially inc exponentially, then starts to plateau - as it's below the run time for ls, it can also be called sublinear runtimes
#
# 4. bs has a precondition - the input set has to be sorted and sorting algos has varying complexities thf have to do additional work prior to bs
# thf ls ends up being more perfromant up to a certain val of n as combo of sorting first then doing bs adds up
#
# 5. Common complexities - common vals of Big O
#     - O(n) = Linear Time = when the num of operatiosn to dtermine the results in the worstcase scenario, is as much as n - any algo that sequentially reads the input will have linear time
#     - O(n^2)= Quadratic Time = operation raised to the second power / sqaured -for any given vlaue of n, n**n operations are carried out - if n=4, then it would be a 4x4 matrix - maasny search algos have a worst case quadratic runtime
#     - O(n^3) = Cubic Runtime aren't as common as quadratic -but quadratic and cubic are very computationally intensiice
#     - O(n log n) = Quasilinear Runtimes - fo a logarithmic run time and then multiple it by a linear runtime - lies b/w a linear and quadratic runtime - seen in sorting algos such as merge sort which has a worst case scenario of this
#     - O(log n) = O(ln n) = logarithmic runtime - as n grows really large, the num of operations initially inc exponentially, then starts to plateau - as it's below the run time for ls, it can also be called sublinear runtimes
#     - O(n^k) = Polynomial runtime where k = any value - considered efficient algos and likely to be used
#     - O(x^n) = Exponential runtimes = too expensive to be used e..g brute force algo which is searching through each individual val until stumble on te right one e.g. if there's a lock with 2 dails and numbers on each lokc rainign from 0-9 - it means that there are 10 options across 2 dials -> 10^2 where 2 = n. As n inc, the num of ops inc till it's unsolvable in a realsitc amount of time
#         - O(n!) another type of exponential runtime = best vislaised with the analogy of the travelling salesman - factorial aka n! = n(n-1)(n-2)...(2)(1) - factorial = combinatorial runtime - at low vals of n, these can be used, but larger n will take longer runtimes that the time tat humans have existed
#
# 6. Types of sorting algos
# - Merge sort - split a list evenly and from the middle into sub lists continously until you have multiple lists, each consisting of just 1 element which is where n=0. Then when ding to just one element, do one sort operation and merge one sublist to another back in the opposite direction whenre n=1 when 2 sublists are merged, n=2 when 3 are merged and onwards. The first hald of merge sort = splitting the list into half which is seen in bs where each comaprsion operation, cuts down the range to half the vals and  which has the worst case runtime of O(log n). Then need to do comporison operations and we do n num of comparision ops which -> O(n log n)
#
# 7. Determining complexity of an algo
#     - each step in a given algo can have diff rt
#     e.g. in bs - assuming list is sorted. 1. find the middle of the list = contant time O(1) - don't ned to walk through the list to determine the size. 2. Compare elelemnt in middle position with target = O(1). 3. Best case run time for bs = O(1) - if the target is the middle element- this is  Linear time O(n) - to know the size of list by walking through each element within the list . 4. If not best case - Splitting into sublists and comapring until the val target val is reached is O(log n) as discard half of vals eveytime
#         - thf bs = xxx constant time and 1 step than is logarithmic
#         when eval an algo, the algo runtime = the least efficient step in the algo
#         thf bs has a logarithmic run time O(log n)
#         algos don't always reach their worst case, but there are the avergae case scenarios inbetween best and worst case

# %% [markdown]
# ##### Introduction to Algorithms - Recursion and Space Complexity

# %% [markdown]
# Space complexity
# - Time complexity = how the run time of an algo grows as n grows longer
# - Space complexity is a measure of how much working storage or extra storage is needed as a specific algo grows - everything requires space and must be taken in mind when writing algos to ensure they perform as well as they can when data grows large
#     - measured using Big O notation inthe worst case scenrio
#     - example using binary search
#         - solution relies eavily on first and last vars - whenn eliinate a set of vals, we don't create a sublist, we just redefine first and last to point to a diff section of the list
#         - the algo only considers the vals first and last in respect to the midpoint, by redef it, e can find a solution using just the origina list
#         - thf for any val of n - the space complexity = O(1) aka the iterative version of binary search takes constant space
#         - as n grows more storage needs to account for a alrger list size but sapce complexity is considering the ADDITONAL storage that is requuired as the algo runs - the amount of storage does not get larger than n for bs
#     - exmaple using recursive binary search
#         - don't use vars to keep track of which protion of the list we're working with. create new list with subset of vals with every recursive func called
#         - the size of the sublist is dec by a factor by each execution of the algo - this is how bs works and because of this pattern the run time of bs is logarithmic and the space complecity of rbs is logarithmic
#         - rbs runs in logairthmic time O(log n) but this depends on the language - look into tail optimisation (as recursive func is the end of the fucn - swift decs space by doing tail call optimisation / elimination to dec the amount of space but python doesn't use it)
#         - rbs takes logairthmic space. bs takes constant space. both take logitimic time complexity thf want togo with normal bs in python as it runs in stant space
#
# Recap of algos in code
# - algo thinking = aprpoach to pb that incolves breaking prib insto clear input, output and steps to get between them
# - algos need to be very specific in order, the steps need to be disticnt, the ago shoud produce a resut and compete in a finite amount of time
# - big O = time compexity
# - bs = log time and constant space
# - rbs = log time and log space
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Algorithms: Sorting and Searching - Sorting Algorithms

# %% [markdown]
# Sorting and searching
#
# Bogosort
#
# Slection sort
#
# Getting run time of a program
#
# Recusrion
#
# Quicksort
#
# Implementing Quicksort
#
# Merge sort
#
# Actual rt of sorting algos
#
# Big O rt of sorting algos

# %% [markdown]
# ##### Algorithms: Sorting and Searching - Searching Names

# %% [markdown]
# LS
#
# Sorting names
#
# BS
#
# Timing search scripts
#
# Big O rt of search algos
