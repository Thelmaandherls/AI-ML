# %%
# Creating and reading vals from an array 

new_list = [1, 2, 3]
# This allocates a base amount of memeory for the array (list in python) to use
# In python the vals aren't stored in ememory but stored elsehere in ememory
# and the arrya stores referneces to the vals 
# Use array indexing to access the specific val without  iterating over the 
# entire list as we're assured the moroy uis contgous given that it's an 
# arrya thf access is a conant time / O(1) operation and is also why an array
# errors out when you try to access a value outside the a val outside the array 
# and arrays cal the mory addres on the fly
result = new_list[0]
result

# searching for an item in python can happen in 2 ways 
# in calls a contain method that is def on the list type that runs a ls operation 
if 1 in new_list:
    print(True)

# for loop torun over the list iteratively and do comaprison operstion 
for n in new_list:
    if n == 1: 
        print(True)
        break
# Out:
# True
